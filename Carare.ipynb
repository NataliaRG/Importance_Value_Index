# %% [markdown]
# # Importance Value Index

# %% [markdown]
# #### Stacked bar chats

# %% [markdown]
# This is a project created to calculate the IVI from a dataset of Tropical tree species in Colombia.
# I added features based partially on this video: https://www.youtube.com/watch?v=Sa-TZ72jTds (Thanks a lot!)

# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches 
import matplotlib

# %%
c = pd.read_csv('Carare_Colombia.csv')

# %%
c
# Out:
#                       Especies  Abundancia Relativa  Frecuencia Relativa  \
# 0          Eschweilera reversa            11.781609             3.629032
# 1     Bellucia grossularioides             8.333333             3.225806
# 2          Tapirira guianensis             6.034483             2.419355
# 3                     Inga sp              5.316092             3.225806
# 4                  Duguetia sp             3.448276             2.822581
# 5           Xylopia aromatica              4.310345             1.612903
# 6             Luehea seemannii             0.431034             0.403226
# 7          Pseudolmedia laevis             2.586207             3.629032
# 8                 Eclinussa sp             2.155172             2.822581
# 9            Dialium guianense             1.436782             2.419355
# 10                   Virola sp             2.586207             2.016129
# 11        Protium heptaphyllum             2.298851             2.419355
# 12         Xylopia colombiana              2.011494             2.016129
# 13                  Miconia sp             1.724138             2.419355
# 14   Pourouma hirsutipetiolata             1.436782             2.016129
# 15           Brosimun potabile             1.293103             1.612903
# 16        Brachycylix vageleri             0.862069             1.612903
# 17             Virola sebifera             1.724138             1.209677
# 18                  Xylopia sp             1.867816             1.209677
# 19            Iryanthera ulei              1.580460             2.016129
# 20      Alchornea schomburgkii             0.574713             0.403226
# 21              Andira inermis             1.580460             0.806452
# 22            Jacaranda copaia             1.436782             1.612903
# 23              Brosimun utile             1.005747             2.016129
# 24             Cupania cinerea             1.149425             1.612903
# 25                Alchornea sp             1.005747             1.209677
# 26                  Andira sp              1.149425             2.016129
# 27          Xylopia columbiana             1.149425             0.403226
# 28        Sterculia colombiana             1.149425             1.612903
# 29  Clathrotropis brachypetala             1.005747             1.209677
#
#     Dominancia Relativa   IVI 300%   IVI 100%
# 0             14.812518  30.223160  10.074387
# 1              3.273837  14.832977   4.944326
# 2              6.264836  14.718673   4.906224
# 3              5.119876  13.661774   4.553925
# 4              2.357746   8.628603   2.876201
# 5              2.449581   8.372829   2.790943
# 6              7.394518   8.228779   2.742926
# 7              1.043544   7.258784   2.419595
# 8              1.668000   6.645753   2.215251
# 9              2.728102   6.584238   2.194746
# 10             1.755898   6.358234   2.119411
# 11             1.554934   6.273139   2.091046
# 12             1.817545   5.845168   1.948389
# 13             1.481745   5.625237   1.875079
# 14             1.340612   4.793523   1.597841
# 15             1.873579   4.779586   1.593195
# 16             2.164009   4.638981   1.546327
# 17             1.640555   4.574370   1.524790
# 18             1.425321   4.502815   1.500938
# 19             0.637727   4.234316   1.411439
# 20             3.239411   4.217349   1.405783
# 21             1.811885   4.198796   1.399599
# 22             1.056570   4.106254   1.368751
# 23             1.046700   4.068576   1.356192
# 24             0.948455   3.710784   1.236928
# 25             1.487010   3.702434   1.234145
# 26             0.522292   3.687846   1.229282
# 27             1.902907   3.455558   1.151853
# 28             0.683434   3.445763   1.148588
# 29             1.112539   3.327963   1.109321

# %%
#Data
bar_stack1 = c['Abundancia Relativa']
bar_stack2 = c['Frecuencia Relativa']
bar_stack3 = c['Dominancia Relativa']
x = np.arange(len(bar_stack1))

#Plot
f, ax = plt.subplots(1, figsize=(10,5))
plt.bar(x, bar1, color='#8673a1', edgecolor='black')
plt.bar(x, bar2, color='#641c34', bottom=bar_stack1, edgecolor='black')
plt.bar(x, bar3, color='#ffffbf', bottom=list(map(lambda x,y: x+y, bar_stack1, bar_stack2)), edgecolor='black')

#Labels
plt.xticks(x, c['Especies'], rotation=90)
plt.ylabel('IVI')
plt.xlabel('Especies')
plt.title('Indice de Valor de Importancia')

#Legend
light_purple_patch = mpatches.Patch(color='#8673a1', label= 'Abundancia Relativa')
dullpink_patch = mpatches.Patch(color='#641c34', label= 'Frecuencia Relativa')
pale_yellow_patch = mpatches.Patch(color='#ffffbf', label= 'Dominancia Relativa')
plt.legend(handles= [pale_yellow_patch, dullpink_patch, light_purple_patch], loc='upper right', shadow=True, edgecolor='black')

# %% [markdown]
# <br>Natalia Ramirez Gil</br>
# <br>Data Scientist at Ashara Studios https://www.facebook.com/AsharaStudios/</br>
# <br>September 2018</br>
